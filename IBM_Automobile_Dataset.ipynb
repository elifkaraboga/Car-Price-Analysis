# %%
#import pandas as library

import pandas as pd
import numpy as np

# %%
# Read the online file by the URL provides above, and assign it to variable "df"

other_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"

df = pd.read_csv(other_path , header = None)

# %%
# show the first 5 rows using dataframe.head() method

print("The first 5 rows of the dataframe")
df.head(5)
# Out:
# The first 5 rows of the dataframe
#    0    1            2    3    4     5   ...    20   21    22  23  24     25
# 0   3    ?  alfa-romero  gas  std   two  ...   9.0  111  5000  21  27  13495
# 1   3    ?  alfa-romero  gas  std   two  ...   9.0  111  5000  21  27  16500
# 2   1    ?  alfa-romero  gas  std   two  ...   9.0  154  5000  19  26  16500
# 3   2  164         audi  gas  std  four  ...  10.0  102  5500  24  30  13950
# 4   2  164         audi  gas  std  four  ...   8.0  115  5500  18  22  17450
#
# [5 rows x 26 columns]

# %%
#show the bottom 10 rows of the dataframe

print("The bottom 10 rows of the dataframe")
df.tail(10)
# Out:
# The bottom 10 rows of the dataframe
#      0    1      2       3      4     5   ...    20   21    22  23  24     25
# 195  -1   74  volvo     gas    std  four  ...   9.5  114  5400  23  28  13415
# 196  -2  103  volvo     gas    std  four  ...   9.5  114  5400  24  28  15985
# 197  -1   74  volvo     gas    std  four  ...   9.5  114  5400  24  28  16515
# 198  -2  103  volvo     gas  turbo  four  ...   7.5  162  5100  17  22  18420
# 199  -1   74  volvo     gas  turbo  four  ...   7.5  162  5100  17  22  18950
# 200  -1   95  volvo     gas    std  four  ...   9.5  114  5400  23  28  16845
# 201  -1   95  volvo     gas  turbo  four  ...   8.7  160  5300  19  25  19045
# 202  -1   95  volvo     gas    std  four  ...   8.8  134  5500  18  23  21485
# 203  -1   95  volvo  diesel  turbo  four  ...  23.0  106  4800  26  27  22470
# 204  -1   95  volvo     gas  turbo  four  ...   9.5  114  5400  19  25  22625
#
# [10 rows x 26 columns]

# %%
#Add header to our dataset to better describe our data

headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

print("headers\n", headers)
# Out:
# headers
#  ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
df.columns = headers
df.head(10)
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
# 5          2                 ?         audi  ...       19          25  15250
# 6          1               158         audi  ...       19          25  17710
# 7          1                 ?         audi  ...       19          25  18920
# 8          1               158         audi  ...       17          20  23875
# 9          0                 ?         audi  ...       16          22      ?
#
# [10 rows x 26 columns]

# %%
#We need to replace the "?" symbol with NaN so the dropna() can remove the missing values:

df1=df.replace('?',np.NaN)

# %%
#We can drop missing values along the column "price" as follows:

df=df1.dropna(subset=["price"], axis=0)
df.head(20)
# Out:
#     symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0           3               NaN  alfa-romero  ...       21          27  13495
# 1           3               NaN  alfa-romero  ...       21          27  16500
# 2           1               NaN  alfa-romero  ...       19          26  16500
# 3           2               164         audi  ...       24          30  13950
# 4           2               164         audi  ...       18          22  17450
# 5           2               NaN         audi  ...       19          25  15250
# 6           1               158         audi  ...       19          25  17710
# 7           1               NaN         audi  ...       19          25  18920
# 8           1               158         audi  ...       17          20  23875
# 10          2               192          bmw  ...       23          29  16430
# 11          0               192          bmw  ...       23          29  16925
# ...

# %%
#Now our task is finding the names of the columns of the dataframe

for col in df.columns:         #or print(df.columns)
    print(col)
# Out:
# symboling
# normalized-losses
# make
# fuel-type
# aspiration
# num-of-doors
# body-style
# drive-wheels
# engine-location
# wheel-base
# length
# width
# height
# curb-weight
# engine-type
# num-of-cylinders
# engine-size
# fuel-system
# bore
# stroke
# compression-ratio
# horsepower
# peak-rpm
# city-mpg
# highway-mpg
# price

# %%
#Saving dataset

df.to_csv("automobile.csv", index=False)      #index = False means the row names will not be written

# %% [markdown]
# **Exploring the Basic Insights of the Dataset**

# %%
#Let's explore the data types of the dataset since it has a variety of types

df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#Describing data: This method will provide various summary statistics, excluding NaN (Not a Number) values.

df.describe()
# Out:
#         symboling  wheel-base  ...    city-mpg  highway-mpg
# count  201.000000  201.000000  ...  201.000000   201.000000
# mean     0.840796   98.797015  ...   25.179104    30.686567
# std      1.254802    6.066366  ...    6.423220     6.815150
# min     -2.000000   86.600000  ...   13.000000    16.000000
# 25%      0.000000   94.500000  ...   19.000000    25.000000
# 50%      1.000000   97.000000  ...   24.000000    30.000000
# 75%      2.000000  102.400000  ...   30.000000    34.000000
# max      3.000000  120.900000  ...   49.000000    54.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# If we include all, it provides the statistical summary of all the columns, including object-typed attributes.

# %%
df.describe(include = "all")
# Out:
#          symboling normalized-losses    make  ...    city-mpg highway-mpg price
# count   201.000000               164     201  ...  201.000000  201.000000   201
# unique         NaN                51      22  ...         NaN         NaN   186
# top            NaN               161  toyota  ...         NaN         NaN  8921
# freq           NaN                11      32  ...         NaN         NaN     2
# mean      0.840796               NaN     NaN  ...   25.179104   30.686567   NaN
# std       1.254802               NaN     NaN  ...    6.423220    6.815150   NaN
# min      -2.000000               NaN     NaN  ...   13.000000   16.000000   NaN
# 25%       0.000000               NaN     NaN  ...   19.000000   25.000000   NaN
# 50%       1.000000               NaN     NaN  ...   24.000000   30.000000   NaN
# 75%       2.000000               NaN     NaN  ...   30.000000   34.000000   NaN
# max       3.000000               NaN     NaN  ...   49.000000   54.000000   NaN
#
# ...

# %%
df[['length', 'compression-ratio']].describe()
# Out:
#            length  compression-ratio
# count  201.000000         201.000000
# mean   174.200995          10.164279
# std     12.322175           4.004965
# min    141.100000           7.000000
# 25%    166.800000           8.600000
# 50%    173.200000           9.000000
# 75%    183.500000           9.400000
# max    208.100000          23.000000

# %%
#Another way to check our dataset is:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...
